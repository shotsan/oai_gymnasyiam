# %%
# !pip install gymnasium

# %%
# !pip install swig
# !pip install box2d box2d-kengz

# %%
import gym
env = gym.make("LunarLander-v2", render_mode="human") # change to any env following gymnasium definition
env.reset(seed=123, options={}) # use any seed here

done = False
while not done:
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, info = env.step(action)

    done = terminated

env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %% [markdown]
# Gym uses observation, which is next state![AE_loop.png](data:image/png;base64,...)

# %%
# for running a long simulation of random actions
env = gym.make("LunarLander-v2", render_mode="human")
env.reset()

for _ in range(1000):
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, info = env.step(action)

env.close()

# %%
# render view of gym environments

# !apt-get install python-opengl -y

# !apt install xvfb -y

# !pip install pyvirtualdisplay

# !pip install piglet

# %%
from pyvirtualdisplay import Display
Display().start()

import gym
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('CartPole-v0')
env.reset()
img = plt.imshow(env.render('rgb_array')) # only call this once
for _ in range(40):
    img.set_data(env.render('rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    action = env.action_space.sample()
    env.step(action)

# %%
# using RL DQN now.
https://github.com/vwxyzjn/cleanrl

For this point onwards, I don't recommend using Colab, since there is a lot going on, with installations,

Above link all the algorithm implemenatation that only needs to stitched.
